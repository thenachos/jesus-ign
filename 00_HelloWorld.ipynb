# %% [markdown]
# ##PRIMER PROGRAMA
#
# Hola mundo

# %%
print("Hola Mundo")
n1 = int(input("Ingrese el Primer Número:"))
n2 = int(input("Ingrese el Segundo Número:"))
suma = n1 + n2
print(f"La suma de los dos Números es: {suma}")

# %% [markdown]
# ##SEGUNDO PROGRAMA
#
# <p>Promedio</p>

# %%
print("Hola Estudiante, Bienvenido a la Calculadora de Promedios")
n1 = float(input("Ingrese su Primer Calificación:"))
n2 = float(input("Ingrese su Segunda Calificación:"))
n3 = float(input("Ingrese su Tercera Calificación:"))
n4 = float(input("Ingrese su Cuarta Calificación:"))
n5 = float(input("Ingrese su Quinta Calificación:"))
n6 = float(input("Ingrese su Sexta Calificación:"))
n7 = float(input("Ingrese su Septima Calificación:"))
n8 = float(input("Ingrese su Octava Calificación:"))
n9 = float(input("Ingrese su Novena Calificación:"))
n10 = float(input("Ingrese su Decima Calificación:"))
suma = ( n1 +n2 + n3 + n4 + n5 + n6 + n7 + n8 + n9 + n10 ) / 10
print(f"Su promedio es: {suma}")
111110
